# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart_2020_cleaned.csv')
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female        55-59     White      Yes
# 1                0.0          No  Female  80 or older     White       No
# 2               30.0          No    Male        65-69     White      Yes
# 3                0.0          No  Female        75-79     White       No
# 4                0.0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]

# %%
df.head()

# %%
#Histogram distribution of BMI for those with heart disease 
df['BMI'].where(df['HeartDisease'] == 'Yes').plot(kind='hist')

# %%
#Bar Chart Average BMI, Physical Health, Mental Health, SleepTime for all those with Heart Disease
titles = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]
df[titles].where(df['HeartDisease'] == 'Yes').mean().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
#Bar Chart Average BMI, Physical Health, Mental Health, SleepTime for all those without Heart Disease
titles = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]
df[titles].where(df['HeartDisease'] == 'No').mean().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
#How does substance use (Alcohol and smoking) affect heart disease
#Pie chart showing percentages of people who have heart disease that smoke and percent of people who have heart disease that drink
#2 separate pie charts for each
#chart of people who smoke and have heart disease
df = pd.read_csv('heart_2020_cleaned.csv')
for i in df['Smoking']:
    s1 = df['Smoking'].where(df['HeartDisease'] == 'Yes').value_counts()['Yes']
    s2 = df['Smoking'].where(df['HeartDisease'] == 'Yes').value_counts()['No']
sum = 319795
p1 = s1/sum
p2 = s2/sum
sizes = [p1, p2]
labels = ["Smokers with Heart Disease", "Non-Smokers with Heart disease"]
plt.pie(sizes, labels)
plt.show()

#chart of people who drink and have heart disease
for i in df['AlcoholDrinking']:
    s1 = df['AlcoholDrinking'].where(df['HeartDisease'] == 'Yes').value_counts()['Yes']
    s2 = df['AlcoholDrinking'].where(df['HeartDisease'] == 'Yes').value_counts()['No']
sum = 319795
p1 = s1/sum
p2 = s2/sum
sizes = [p1, p2]
labels = ["Drinkers with Heart Disease", "Non-Drinkers with Heart disease"]
plt.pie(sizes, labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [57], in <cell line: 6>()
#       6 for i in df['Smoking']:
#       7     s1 = df['Smoking'].where(df['HeartDisease'] == 'Yes').value_counts()['Yes']
# ----> 8     s2 = df['Smoking'].where(df['HeartDisease'] == 'Yes').value_counts()['No']
#       9 sum = 319795
#      10 p1 = s1/sum
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py:5569, in Series.where(self, cond, other, inplace, axis, level, errors, try_cast)
#    5556 @deprecate_nonkeyword_arguments(
#    5557     version=None, allowed_args=["self", "cond", "other"]
#    5558 )
#    (...)
#    5567     try_cast=lib.no_default,
#    5568 ):
# -> 5569     return super().where(cond, other, inplace, axis, level, errors, try_cast)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:9318, in NDFrame.where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9310 if try_cast is not lib.no_default:
#    9311     warnings.warn(
#    9312         "try_cast keyword is deprecated and will be removed in a "
#    9313         "future version.",
#    9314         FutureWarning,
#    9315         stacklevel=find_stack_level(),
#    9316     )
# -> 9318 return self._where(cond, other, inplace, axis, level, errors=errors)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:9160, in NDFrame._where(self, cond, other, inplace, axis, level, errors)
#    9157     return self._update_inplace(result)
#    9159 else:
# -> 9160     new_data = self._mgr.where(
#    9161         other=other,
#    9162         cond=cond,
#    9163         align=align,
#    9164     )
#    9165     result = self._constructor(new_data)
#    9166     return result.__finalize__(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py:324, in BaseBlockManager.where(self, other, cond, align)
#     321     align_keys = ["cond"]
#     322     other = extract_array(other, extract_numpy=True)
# --> 324 return self.apply(
#     325     "where",
#     326     align_keys=align_keys,
#     327     other=other,
#     328     cond=cond,
#     329 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py:293, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     289 if isinstance(obj, (ABCSeries, ABCDataFrame)):
#     290     # The caller is responsible for ensuring that
#     291     #  obj.axes[-1].equals(self.items)
#     292     if obj.ndim == 1:
# --> 293         kwargs[k] = obj.iloc[b.mgr_locs.indexer]._values
#     294     else:
#     295         kwargs[k] = obj.iloc[:, b.mgr_locs.indexer]._values
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:966, in _LocationIndexer.__getitem__(self, key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
# --> 966     maybe_callable = com.apply_if_callable(key, self.obj)
#     967     return self._getitem_axis(maybe_callable, axis=axis)
#
# KeyboardInterrupt:

# %%
#BAr charts showing how other medical conditions relate to heart Disease
